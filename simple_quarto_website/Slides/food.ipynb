# %% [raw]
# ---
# title: "Food"
# author: "Ruikun Chen"
# format: revealjs
# bibliography: ../reference.bib
# ---

# %% [markdown]
# ## Lunch
#
# - Rice
# - Soup[@vandiver1977black]
#
# ## Dinner
#
# - noodles
# - Java

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]
plt.figure()
plt.plot(x, y, marker='o')
plt.title('Sample Plot')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.show()

# %% [markdown]
# ## Breakfast
#
# - nothing
# ![image](./images/1.png)
